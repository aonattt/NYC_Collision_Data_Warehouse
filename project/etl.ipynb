# %%
pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
# Out:
# Collecting https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
#   Using cached https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
# Requirement already satisfied: joblib~=1.1.0 in c:\users\kven\anaconda3\lib\site-packages (from pandas-profiling==3.1.1) (1.1.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\kven\anaconda3\lib\site-packages (from pandas-profiling==3.1.1) (1.6.2)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\kven\anaconda3\lib\site-packages (from pandas-profiling==3.1.1) (1.3.4)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\kven\anaconda3\lib\site-packages (from pandas-profiling==3.1.1) (3.4.3)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\kven\anaconda3\lib\site-packages (from pandas-profiling==3.1.1) (1.8.2)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\kven\anaconda3\lib\site-packages (from pandas-profiling==3.1.1) (5.3)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\kven\anaconda3\lib\site-packages (from pandas-profiling==3.1.1) (2.11.1)
# Requirement already satisfied: markupsafe~=2.0.1 in c:\users\kven\anaconda3\lib\site-packages (from pandas-profiling==3.1.1) (2.0.1)
# Collecting visions[type_image_path]==0.7.4
#   Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\kven\anaconda3\lib\site-packages (from pandas-profiling==3.1.1) (1.18.1)
# Processing c:\users\kven\appdata\local\pip\cache\wheels\70\e1\52\5b14d250ba868768823940c3229e9950d201a26d0bd3ee8655\htmlmin-0.1.12-py3-none-any.whl
# Collecting missingno>=0.4.2
#   Using cached missingno-0.5.0-py3-none-any.whl (8.8 kB)
# Collecting phik>=0.11.1
#   Using cached phik-0.12.0-cp37-cp37m-win_amd64.whl (660 kB)
# Collecting tangled-up-in-unicode==0.2.0
#   Using cached tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
# Collecting requests>=2.24.0
#   Using cached requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting tqdm>=4.48.2
#   Using cached tqdm-4.62.3-py2.py3-none-any.whl (76 kB)
# Collecting seaborn>=0.10.1
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# Collecting multimethod>=1.4
#   Using cached multimethod-1.6-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: pytz>=2017.3 in c:\users\kven\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling==3.1.1) (2019.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\kven\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling==3.1.1) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kven\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.1) (7.0.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kven\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.1) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kven\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.1) (1.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kven\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.1) (2.4.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\kven\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling==3.1.1) (3.10.0.2)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\kven\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling==3.1.1) (19.3.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\kven\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling==3.1.1) (2.4)
# Processing c:\users\kven\appdata\local\pip\cache\wheels\4c\d5\59\5e3e297533ddb09407769762985d134135064c6831e29a914e\imagehash-4.2.1-py2.py3-none-any.whl
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\users\kven\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling==3.1.1) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kven\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling==3.1.1) (2020.6.20)
# Collecting charset-normalizer~=2.0.0; python_version >= "3"
#   Using cached charset_normalizer-2.0.7-py3-none-any.whl (38 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kven\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling==3.1.1) (1.25.8)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\kven\anaconda3\lib\site-packages (from tqdm>=4.48.2->pandas-profiling==3.1.1) (0.4.3)
# Requirement already satisfied: six>=1.5 in c:\users\kven\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling==3.1.1) (1.14.0)
# Requirement already satisfied: setuptools in c:\users\kven\anaconda3\lib\site-packages (from kiwisolver>=1.0.1->matplotlib>=3.2.0->pandas-profiling==3.1.1) (45.2.0.post20200210)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\kven\anaconda3\lib\site-packages (from networkx>=2.4->visions[type_image_path]==0.7.4->pandas-profiling==3.1.1) (4.4.1)
# Requirement already satisfied: PyWavelets in c:\users\kven\anaconda3\lib\site-packages (from imagehash; extra == "type_image_path"->visions[type_image_path]==0.7.4->pandas-profiling==3.1.1) (1.1.1)
# Building wheels for collected packages: pandas-profiling
#   Building wheel for pandas-profiling (setup.py): started
#   Building wheel for pandas-profiling (setup.py): finished with status 'done'
#   Created wheel for pandas-profiling: filename=pandas_profiling-3.1.1-py2.py3-none-any.whl size=261278 sha256=8332707824ce3a7bcc1aa6d702a5aa65c86eea3a2186f83c1678ff347b15fe83
#   Stored in directory: C:\Users\Kven\AppData\Local\Temp\pip-ephem-wheel-cache-jy1mxo7t\wheels\cc\d5\09\083fb07c9363a2f45854b0e3a7de7d7c560f07da74b9e9769d
# Successfully built pandas-profiling
# Installing collected packages: tangled-up-in-unicode, multimethod, imagehash, visions, htmlmin, seaborn, missingno, phik, charset-normalizer, requests, tqdm, pandas-profiling
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.10.0
#     Uninstalling seaborn-0.10.0:
#       Successfully uninstalled seaborn-0.10.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.22.0
#     Uninstalling requests-2.22.0:
#       Successfully uninstalled requests-2.22.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.42.1
#     Uninstalling tqdm-4.42.1:
#       Successfully uninstalled tqdm-4.42.1
# Successfully installed charset-normalizer-2.0.7 htmlmin-0.1.12 imagehash-4.2.1 missingno-0.5.0 multimethod-1.6 pandas-profiling-3.1.1 phik-0.12.0 requests-2.26.0 seaborn-0.11.2 tangled-up-in-unicode-0.2.0 tqdm-4.62.3 visions-0.7.4
# Note: you may need to restart the kernel to use updated packages.
# ERROR: conda 4.10.3 requires ruamel_yaml_conda>=0.11.14, which is not installed.

# %%
pip install petl
# Out:
# Collecting petl
#   Downloading petl-1.7.4.tar.gz (245 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Building wheels for collected packages: petl
#   Building wheel for petl (PEP 517): started
#   Building wheel for petl (PEP 517): finished with status 'done'
#   Created wheel for petl: filename=petl-1.7.4-py3-none-any.whl size=217003 sha256=7691e0e61626d7ccde976cc0bb8d021212116b22c52a438650640f2f20390225
#   Stored in directory: c:\users\kven\appdata\local\pip\cache\wheels\75\23\fb\a0e8e350a8718579b0cde55163df77b94de835d7d116388fa5
# Successfully built petl
# Installing collected packages: petl
# Successfully installed petl-1.7.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from google.cloud import bigquery
from google.oauth2 import service_account
from pandas_profiling import ProfileReport
#from sodapy import Socrata
import pyarrow
import json
import requests
import os
import sys
import argparse
import petl as etl
from datetime import datetime

# %% [markdown]
# # Data Extraction #

# %%
def extract_CSV(csv_location:str):
    print("-----\n extracting data from CSV")
    try:
        df = pd.read_csv(csv_location)
        if len(df) > 0:
            print(f"{len(df)} rows extracted \n-----")
            return df
        else:
            print(f"{csv_location} has 0 rows of data")
    except:
            print(f"{csv_location} extraction failed")

# %% [markdown]
# # Data Profiling #

# %%
def sample_data_profiling(df,df_name:str):
    # Sample 1.000.000 rows
    sample = df.sample(1000000)

    profile = ProfileReport(sample, minimal=True)
    profile.to_file(f"{df_name}.html")
    profile.to_widgets()

# %%
def detailed_data_profiling(df, df_name:str):
    print('='*10)
    print(f"{df_name} -- data profiling:")
    print(f"number of rows {df.shape[0]}")
    print(f"number of columns {df.shape[1]}")
    print('-'*5)
    print(f"column names: {df.columns}")
    print('-'*5)
    print("column data types:")
    for i in df.columns:
        print(f"{i} -- dtype: {df[i].dtypes}")
    print('-'*5)
    print("Columns with null values:")
    print(df.isnull().sum())
    print('-'*5)
    print("the percentage of nulls in every column:")
    print(df.isna().sum()/(len(df))*100)
    print('-'*5)
    print("number of duplicate rows:")
    print(df.duplicated().sum())
    print('-'*5)
    print("numeric column statistics:")
    print(df.describe())
    print('='*10)

# %% [markdown]
# # Data Cleaning

# %%
def drop_unused_columns(df,to_drop:list):
    dropped_df = df.drop(to_drop, axis=1)
    return dropped_df

# %%
def perform_data_cleansing(df,
                               df_name:str,
                               null_values_approach = "drop",
                               duplicates_approach = "keep_first",
                               outliers_approach = 3,
                               outlier_columns = None):
        print('='*10)
        print(f"cleaning {df_name} \n-----")
        
        # remove or replace Null values
        print(f"{df_name} Null values cleaning method: {null_values_approach}")
        if null_values_approach == "drop":
            print(f"dropping {len(df[df.isna().any(axis = 1)])} Null rows")
            df = df.dropna()
            
        elif null_values_approach == "threshold_2":
            df = df.dropna(thresh = 2)
            
        elif null_values_approach == "fill_0":
            df = df.fillna(0)
            
        elif null_values_approach == "ffill":
            df = df.fillna(method = 'ffill')
        
        # handle duplicates
        print(f"-----\n{df_name} duplicate values cleaning method: {duplicates_approach}")
        if duplicates_approach == "keep_first":
            print(f"dropping {df.duplicated().sum()} duplicate rows")
            df.drop_duplicates(keep = "first")
            
        elif duplicates_approach == "keep_last":          
            df.drop_duplicates(keep = "last")
        
        # handle outliers
        if type(outliers_approach) == int and outlier_columns is not None:
            print(f"{df_name} outliers cleaning method: abs {outliers_approach}")
            from scipy import stats
            for c in outlier_columns:
                if df[c].dtypes == "int64" or df[c].dtypes == "float64":
                    df = df[(np.abs(stats.zscore(df[c])) < outliers_approach)]
        print('='*10)
        # return cleaned dataframe
        return df

# %% [markdown]
# # Create Dimension Tables

# %%
 def create_dimension(df,
                         dimension_columns:list, # [first_attribute, second, third]
                         surrogate_key_name:str,
                         surrogate_key_integer_start:int):
        
        print(f"-----\n creating dimension: {dimension_columns[0]}_dim")
        # copy full dataframe to create dimension from subset
        dim = df.copy()
        dim = dim[dimension_columns]
        
        # drop unneeded rows in hierarchy
        dim = dim.drop_duplicates(subset=[dimension_columns[0]], keep = "first")
        
        # add surrogate key
        dim.insert(0, surrogate_key_name, range(surrogate_key_integer_start,
                                                surrogate_key_integer_start+len(dim)))
        
        print(f"dimension {dimension_columns[0]}_dim created with {len(dim)} rows \n-----")
        # return the dimension as a dataframe
        return dim

# %% [markdown]
# # Create Fact Tables

# %%
def create_fact(df,
                    dimensions:list,
                    date_column = None):
        
        print(f"-----\n creating fact table")
        # copy full dataframe to create fact table
        fact = df.copy()
        
        # for every dimension, add the FK to the Fact table and remove hierarchy
        for d in dimensions:
                
            fact = fact.merge(d[[d.columns[0], d.columns[1]]],
                              left_on = d.columns[1],
                              right_on = d.columns[1],
                              how = 'left')
            
            for c in range(1, len(d.columns)):
                fact = fact.drop(d.columns[c], 1)
        
        # create date_id column in fact table to match date_dim        
        if date_column != None:
            
            import datetime as dt
            fact["date_id"] = df[date_column].dt.strftime("%m%d%Y")
            
            if date_column != "date_id":
                
                fact = fact.drop(date_column, 1)
        
        # return fact table as a dataframe        
        print(f"fact table created with {len(fact)} rows \n-----")
        return fact

# %% [markdown]
# # Create Bigquerry Client

# %%
def establish_bigquery_connection(key_path:str,
                                      scopes_url = r'https://www.googleapis.com/auth/cloud-platform'):
        # created bigquery credentials from service account key json file
        credentials = service_account.Credentials.from_service_account_file(key_path)
        
        # initiate the bigquery client with the credentials
        client = bigquery.Client(credentials=credentials, project=credentials.project_id)
        
        # return the bigquery client
        return client

# %% [markdown]
# # Load Tables to Bigquery

# %%
def load_table_to_bigquery(bq_client,
                               table,
                               dataset_name:str,
                               table_name:str):
        
        print(f"-----\n loading {table_name} to BigQuery dataset {dataset_name}")
        # define bigquery client
        client = bq_client
        
        # define location you will upload table to in bigquery
        table_ref = client.dataset(dataset_name).table(table_name)
        
        # configure load job settings
        job_config = bigquery.LoadJobConfig()
        job_config.autodetect = True
        job_config.source_format = bigquery.SourceFormat.CSV
        job_config.write_disposition = "WRITE_TRUNCATE"
        
        # initiate load job
        load_job = client.load_table_from_dataframe(table, table_ref,
                                                    job_config=job_config)
        load_job.result()
        
        # Make a BigQuery API request to check if new table was loaded successfully
        validate_table = client.get_table(table_ref)  # Make an API request.
        print(f"Loaded {validate_table.num_rows} rows and {len(validate_table.schema)} columns to {table_ref} \n-----")

# %% [markdown]
# # Extract & Analyze Person Data

# %%
person_df = extract_CSV('Motor_Vehicle_Collisions_-_Person.csv')
# Out:
# -----
#  extracting data from CSV
# 4486018 rows extracted
# -----

# %%
#sample_data_profiling(person_df, 'Person Data')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
detailed_data_profiling(person_df, 'Person Data')
# Out:
# ==========
# Person Data -- data profiling:
# number of rows 4486018
# number of columns 21
# -----
# column names: Index(['UNIQUE_ID', 'COLLISION_ID', 'CRASH_DATE', 'CRASH_TIME', 'PERSON_ID',
#        'PERSON_TYPE', 'PERSON_INJURY', 'VEHICLE_ID', 'PERSON_AGE', 'EJECTION',
#        'EMOTIONAL_STATUS', 'BODILY_INJURY', 'POSITION_IN_VEHICLE',
#        'SAFETY_EQUIPMENT', 'PED_LOCATION', 'PED_ACTION', 'COMPLAINT',
#        'PED_ROLE', 'CONTRIBUTING_FACTOR_1', 'CONTRIBUTING_FACTOR_2',
#        'PERSON_SEX'],
#       dtype='object')
# -----
# column data types:
# UNIQUE_ID -- dtype: int64
# COLLISION_ID -- dtype: int64
# CRASH_DATE -- dtype: object
# CRASH_TIME -- dtype: object
# PERSON_ID -- dtype: object
# PERSON_TYPE -- dtype: object
# PERSON_INJURY -- dtype: object
# VEHICLE_ID -- dtype: float64
# PERSON_AGE -- dtype: float64
# EJECTION -- dtype: object
# EMOTIONAL_STATUS -- dtype: object
# BODILY_INJURY -- dtype: object
# POSITION_IN_VEHICLE -- dtype: object
# SAFETY_EQUIPMENT -- dtype: object
# PED_LOCATION -- dtype: object
# PED_ACTION -- dtype: object
# COMPLAINT -- dtype: object
# PED_ROLE -- dtype: object
# CONTRIBUTING_FACTOR_1 -- dtype: object
# CONTRIBUTING_FACTOR_2 -- dtype: object
# PERSON_SEX -- dtype: object
# -----
# Columns with null values:
# UNIQUE_ID                      0
# COLLISION_ID                   0
# CRASH_DATE                     0
# CRASH_TIME                     0
# PERSON_ID                     19
# PERSON_TYPE                    0
# PERSON_INJURY                  0
# VEHICLE_ID                176324
# PERSON_AGE                413274
# EJECTION                 2191636
# EMOTIONAL_STATUS         2134105
# BODILY_INJURY            2134062
# POSITION_IN_VEHICLE      2191320
# SAFETY_EQUIPMENT         2191385
# PED_LOCATION             4424550
# PED_ACTION               4424651
# COMPLAINT                2134055
# PED_ROLE                  194891
# CONTRIBUTING_FACTOR_1    4425796
# CONTRIBUTING_FACTOR_2    4425879
# PERSON_SEX                520380
# dtype: int64
# -----
# the percentage of nulls in every column:
# UNIQUE_ID                 0.000000
# COLLISION_ID              0.000000
# CRASH_DATE                0.000000
# CRASH_TIME                0.000000
# PERSON_ID                 0.000424
# PERSON_TYPE               0.000000
# PERSON_INJURY             0.000000
# VEHICLE_ID                3.930524
# PERSON_AGE                9.212491
# EJECTION                 48.854820
# EMOTIONAL_STATUS         47.572368
# BODILY_INJURY            47.571410
# POSITION_IN_VEHICLE      48.847775
# SAFETY_EQUIPMENT         48.849224
# PED_LOCATION             98.629787
# PED_ACTION               98.632038
# COMPLAINT                47.571254
# PED_ROLE                  4.344410
# CONTRIBUTING_FACTOR_1    98.657562
# CONTRIBUTING_FACTOR_2    98.659412
# PERSON_SEX               11.600043
# dtype: float64
# -----
# number of duplicate rows:
# 0
# -----
# numeric column statistics:
#           UNIQUE_ID  COLLISION_ID    VEHICLE_ID    PERSON_AGE
# count  4.486018e+06  4.486018e+06  4.309694e+06  4.072744e+06
# mean   8.366608e+06  3.823449e+06  1.816631e+07  3.664893e+01
# std    2.325430e+06  6.385248e+05  1.453921e+06  1.183192e+02
# min    1.092200e+04  3.700000e+01  1.234230e+05 -9.990000e+02
# 25%    6.759801e+06  3.626129e+06  1.744157e+07  2.300000e+01
# 50%    7.904574e+06  3.896870e+06  1.799107e+07  3.500000e+01
# 75%    1.004967e+07  4.172092e+06  1.904292e+07  5.000000e+01
# max    1.201383e+07  4.474258e+06  2.009985e+07  9.999000e+03
# ==========

# %% [markdown]
# # Cleaning Person Data

# %%
pure_person_df = drop_unused_columns(person_df, ['UNIQUE_ID','CRASH_TIME','VEHICLE_ID','EJECTION','EMOTIONAL_STATUS','SAFETY_EQUIPMENT','PED_LOCATION','PED_ACTION','COMPLAINT','CONTRIBUTING_FACTOR_1','CONTRIBUTING_FACTOR_2'])

# %%
clean_person_df = perform_data_cleansing(pure_person_df,
                               'Clean Person Data',
                               null_values_approach = "drop",
                               duplicates_approach = "keep_first",
                               outliers_approach = 3,
                               outlier_columns = None)
# Out:
# ==========
# cleaning Clean Person Data
# -----
# Clean Person Data Null values cleaning method: drop
# dropping 2218480 Null rows
# -----
# Clean Person Data duplicate values cleaning method: keep_first
# dropping 0 duplicate rows
# ==========

# %% [markdown]
# # Create DimPerson Table

# %%
dim_person = create_dimension(clean_person_df,
                         ['PERSON_ID','PERSON_AGE','PERSON_SEX','PERSON_TYPE','PERSON_INJURY','BODILY_INJURY','POSITION_IN_VEHICLE','PED_ROLE','COLLISION_ID'],
                         'ID',
                         1000)
# Out:
# -----
#  creating dimension: PERSON_ID_dim
# dimension PERSON_ID_dim created with 2267538 rows
# -----

# %%
dim_person
# Out:
#               ID                             PERSON_ID  PERSON_AGE PERSON_SEX  \
# 1           1000  4629e500-a73e-48dc-b8fb-53124d124b80        33.0          F
# 4           1001  e038e18f-40fb-4471-99cf-345eae36e064         7.0          F
# 5           1002  84bcb3a7-d201-4c61-9e30-fe29268c1074        27.0          M
# 8           1003  c3fc715e-203f-462d-9e8b-6a41fc378703        36.0          M
# 10          1004  48a63e6b-b696-4a33-935c-05b4c6b70867        30.0          M
# ...          ...                                   ...         ...        ...
# 4486005  2268533  9b86c87c-c6bb-4945-8f8c-baf204ce9341        24.0          F
# 4486006  2268534  587974d6-da4b-4cbf-977b-6712743a9049        38.0          F
# 4486013  2268535  644e0d22-6d5a-4d03-8c12-69f0d0f31f60        22.0          M
# 4486014  2268536  f3368a0f-20e0-42ba-988c-f61f6218568e        43.0          M
# 4486016  2268537  eead3262-0c14-4c18-b6b5-f2d56591dff3        68.0          M
#
#         PERSON_TYPE PERSON_INJURY   BODILY_INJURY  \
# 1          Occupant   Unspecified  Does Not Apply
# 4          Occupant   Unspecified  Does Not Apply
# 5          Occupant       Injured            Back
# 8          Occupant   Unspecified  Does Not Apply
# 10         Occupant   Unspecified  Does Not Apply
# ...             ...           ...             ...
# 4486005    Occupant   Unspecified  Does Not Apply
# 4486006    Occupant   Unspecified  Does Not Apply
# 4486013    Occupant       Injured     Entire Body
# 4486014    Occupant       Injured            Neck
# 4486016    Occupant   Unspecified  Does Not Apply
#
#                                        POSITION_IN_VEHICLE   PED_ROLE  \
# 1        Front passenger, if two or more persons, inclu...  Passenger
# 4        Right rear passenger or motorcycle sidecar pas...  Passenger
# 5                                                   Driver     Driver
# 8                                                   Driver     Driver
# 10                                                  Driver     Driver
# ...                                                    ...        ...
# 4486005  Front passenger, if two or more persons, inclu...  Passenger
# 4486006                                             Driver     Driver
# 4486013                                             Driver     Driver
# 4486014                                             Driver     Driver
# 4486016                                             Driver     Driver
#
#          COLLISION_ID
# 1             4230587
# 4             4231168
# 5             4230743
# 8             4229808
# 10            4230737
# ...               ...
# 4486005       4473965
# 4486006       4473513
# 4486013       4473812
# 4486014       4473578
# 4486016       4473384
#
# [2267538 rows x 10 columns]

# %% [markdown]
# # Extract & Analyze Collision Data

# %%
collision_df = extract_CSV('Motor_Vehicle_Collisions_-_Crashes.csv')
# Out:
# -----
#  extracting data from CSV
# C:\Users\Kven\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.
# 1837353 rows extracted
# -----

# %%
#sample_data_profiling(collision_df, 'Collision Data')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
#detailed_data_profiling(collision_df, 'Collision Data')
# Out:
# ==========
# Collision Data -- data profiling:
# number of rows 1837353
# number of columns 29
# -----
# column names: Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')
# -----
# column data types:
# CRASH DATE -- dtype: object
# CRASH TIME -- dtype: object
# BOROUGH -- dtype: object
# ZIP CODE -- dtype: object
# LATITUDE -- dtype: float64
# LONGITUDE -- dtype: float64
# LOCATION -- dtype: object
# ON STREET NAME -- dtype: object
# CROSS STREET NAME -- dtype: object
# OFF STREET NAME -- dtype: object
# NUMBER OF PERSONS INJURED -- dtype: float64
# NUMBER OF PERSONS KILLED -- dtype: float64
# NUMBER OF PEDESTRIANS INJURED -- dtype: int64
# NUMBER OF PEDESTRIANS KILLED -- dtype: int64
# NUMBER OF CYCLIST INJURED -- dtype: int64
# NUMBER OF CYCLIST KILLED -- dtype: int64
# NUMBER OF MOTORIST INJURED -- dtype: int64
# NUMBER OF MOTORIST KILLED -- dtype: int64
# CONTRIBUTING FACTOR VEHICLE 1 -- dtype: object
# CONTRIBUTING FACTOR VEHICLE 2 -- dtype: object
# CONTRIBUTING FACTOR VEHICLE 3 -- dtype: object
# CONTRIBUTING FACTOR VEHICLE 4 -- dtype: object
# CONTRIBUTING FACTOR VEHICLE 5 -- dtype: object
# COLLISION_ID -- dtype: int64
# VEHICLE TYPE CODE 1 -- dtype: object
# VEHICLE TYPE CODE 2 -- dtype: object
# VEHICLE TYPE CODE 3 -- dtype: object
# VEHICLE TYPE CODE 4 -- dtype: object
# VEHICLE TYPE CODE 5 -- dtype: object
# -----
# Columns with null values:
# CRASH DATE                             0
# CRASH TIME                             0
# BOROUGH                           567462
# ZIP CODE                          567684
# LATITUDE                          214779
# LONGITUDE                         214779
# LOCATION                          214779
# ON STREET NAME                    375420
# CROSS STREET NAME                 660121
# OFF STREET NAME                  1554302
# NUMBER OF PERSONS INJURED             18
# NUMBER OF PERSONS KILLED              31
# NUMBER OF PEDESTRIANS INJURED          0
# NUMBER OF PEDESTRIANS KILLED           0
# NUMBER OF CYCLIST INJURED              0
# NUMBER OF CYCLIST KILLED               0
# NUMBER OF MOTORIST INJURED             0
# NUMBER OF MOTORIST KILLED              0
# CONTRIBUTING FACTOR VEHICLE 1       5295
# CONTRIBUTING FACTOR VEHICLE 2     265878
# CONTRIBUTING FACTOR VEHICLE 3    1711604
# CONTRIBUTING FACTOR VEHICLE 4    1809867
# CONTRIBUTING FACTOR VEHICLE 5    1830066
# COLLISION_ID                           0
# VEHICLE TYPE CODE 1                10082
# VEHICLE TYPE CODE 2               315864
# VEHICLE TYPE CODE 3              1715337
# VEHICLE TYPE CODE 4              1810688
# VEHICLE TYPE CODE 5              1830265
# dtype: int64
# -----
# the percentage of nulls in every column:
# CRASH DATE                        0.000000
# CRASH TIME                        0.000000
# BOROUGH                          30.884756
# ZIP CODE                         30.896839
# LATITUDE                         11.689588
# LONGITUDE                        11.689588
# LOCATION                         11.689588
# ON STREET NAME                   20.432655
# CROSS STREET NAME                35.927827
# OFF STREET NAME                  84.594632
# NUMBER OF PERSONS INJURED         0.000980
# NUMBER OF PERSONS KILLED          0.001687
# NUMBER OF PEDESTRIANS INJURED     0.000000
# NUMBER OF PEDESTRIANS KILLED      0.000000
# NUMBER OF CYCLIST INJURED         0.000000
# NUMBER OF CYCLIST KILLED          0.000000
# NUMBER OF MOTORIST INJURED        0.000000
# NUMBER OF MOTORIST KILLED         0.000000
# CONTRIBUTING FACTOR VEHICLE 1     0.288186
# CONTRIBUTING FACTOR VEHICLE 2    14.470709
# CONTRIBUTING FACTOR VEHICLE 3    93.155969
# CONTRIBUTING FACTOR VEHICLE 4    98.504044
# CONTRIBUTING FACTOR VEHICLE 5    99.603397
# COLLISION_ID                      0.000000
# VEHICLE TYPE CODE 1               0.548724
# VEHICLE TYPE CODE 2              17.191253
# VEHICLE TYPE CODE 3              93.359142
# VEHICLE TYPE CODE 4              98.548727
# VEHICLE TYPE CODE 5              99.614228
# dtype: float64
# -----
# number of duplicate rows:
# 0
# -----
# numeric column statistics:
#            LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  1.622574e+06  1.622574e+06               1.837335e+06
# mean   4.067301e+01 -7.383533e+01               2.815017e-01
# std    1.445266e+00  2.819116e+00               6.755768e-01
# min    0.000000e+00 -2.013600e+02               0.000000e+00
# 25%    4.066845e+01 -7.397559e+01               0.000000e+00
# 50%    4.072168e+01 -7.392801e+01               0.000000e+00
# 75%    4.076907e+01 -7.386669e+01               0.000000e+00
# max    4.334444e+01  0.000000e+00               4.300000e+01
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              1.837322e+06                   1.837353e+06
# mean               1.318223e-03                   5.201722e-02
# std                3.832599e-02                   2.344861e-01
# min                0.000000e+00                   0.000000e+00
# 25%                0.000000e+00                   0.000000e+00
# 50%                0.000000e+00                   0.000000e+00
# 75%                0.000000e+00                   0.000000e+00
# max                8.000000e+00                   2.700000e+01
#
#        NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  \
# count                  1.837353e+06               1.837353e+06
# mean                   6.808708e-04               2.391538e-02
# std                    2.662159e-02               1.545142e-01
# min                    0.000000e+00               0.000000e+00
# 25%                    0.000000e+00               0.000000e+00
# 50%                    0.000000e+00               0.000000e+00
# 75%                    0.000000e+00               0.000000e+00
# max                    6.000000e+00               4.000000e+00
#
#        NUMBER OF CYCLIST KILLED  NUMBER OF MOTORIST INJURED  \
# count              1.837353e+06                1.837353e+06
# mean               9.905554e-05                2.044457e-01
# std                1.000671e-02                6.372933e-01
# min                0.000000e+00                0.000000e+00
# 25%                0.000000e+00                0.000000e+00
# 50%                0.000000e+00                0.000000e+00
# 75%                0.000000e+00                0.000000e+00
# max                2.000000e+00                4.300000e+01
#
#        NUMBER OF MOTORIST KILLED  COLLISION_ID
# count               1.837353e+06  1.837353e+06
# mean                5.311990e-04  2.973905e+06
# std                 2.514259e-02  1.502571e+06
# min                 0.000000e+00  2.200000e+01
# 25%                 0.000000e+00  2.975921e+06
# 50%                 0.000000e+00  3.554856e+06
# 75%                 0.000000e+00  4.014437e+06
# max                 5.000000e+00  4.474258e+06
# ==========

# %% [markdown]
# # Cleaning Collision Data

# %%
collision_df = collision_df.rename(columns={"CRASH DATE":"CRASH_DATE","CRASH TIME":"CRASH_TIME"})

# %%
pure_collision_df = drop_unused_columns(collision_df, ['OFF STREET NAME','CONTRIBUTING FACTOR VEHICLE 3','CONTRIBUTING FACTOR VEHICLE 4','CONTRIBUTING FACTOR VEHICLE 5','VEHICLE TYPE CODE 3','VEHICLE TYPE CODE 4','VEHICLE TYPE CODE 5'])

# %%
clean_collision_df = perform_data_cleansing(pure_collision_df,
                               'Clean Collision Data',
                               null_values_approach = "drop",
                               duplicates_approach = "keep_first",
                               outliers_approach = 3,
                               outlier_columns = None)
# Out:
# ==========
# cleaning Clean Collision Data
# -----
# Clean Collision Data Null values cleaning method: drop
# dropping 1008997 Null rows
# -----
# Clean Collision Data duplicate values cleaning method: keep_first
# dropping 0 duplicate rows
# ==========

# %%
#population information retrieved from data.cityofnewyork.us based on New York City Population By Neighborhood Tabulation Areas
population = []
for value in clean_collision_df['BOROUGH']:
    if value == 'BROOKLYN':
        population.append(4970026)
    elif value == 'BRONX':
        population.append(2717758)
    elif value == 'MANHATTAN':
        population.append(3123068)
    elif value == 'QUEENS':
        population.append(4460101)
    elif value == 'STATEN ISLAND':
        population.append(912458)
        
clean_collision_df['POPULATION'] = population
# Out:
# C:\Users\Kven\anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
clean_collision_df
# Out:
#          CRASH_DATE CRASH_TIME        BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 13       05/21/2019      22:50       BROOKLYN  11201.0  40.697540 -73.983120
# 17       03/31/2021      22:20       BROOKLYN  11234.0  40.626457 -73.918000
# 18       04/06/2021      22:58  STATEN ISLAND  10312.0  40.526894 -74.167280
# 25       04/16/2021      17:40          BRONX  10474.0  40.815000 -73.894020
# 28       04/16/2021      16:35          BRONX  10475.0  40.890076 -73.819855
# ...             ...        ...            ...      ...        ...        ...
# 1837347  07/07/2012      17:35       BROOKLYN  11235.0  40.575802 -73.961137
# 1837348  07/06/2012      15:09      MANHATTAN  10035.0  40.801235 -73.941815
# 1837349  07/03/2012      17:30         QUEENS  11102.0  40.774711 -73.933386
# 1837350  07/01/2012      15:30       BROOKLYN  11236.0  40.645032 -73.919978
# 1837352  07/05/2012      23:00         QUEENS  11367.0  40.719910 -73.809039
#
#                           LOCATION                    ON STREET NAME  \
# 13           (40.69754, -73.98312)                       GOLD STREET
# 17            (40.626457, -73.918)                      RALPH AVENUE
# 18          (40.526894, -74.16728)                    BARCLAY AVENUE
# 25             (40.815, -73.89402)                   GARRISON AVENUE
# 28         (40.890076, -73.819855)                       BOSTON ROAD
# ...                            ...                               ...
# 1837347  (40.5758019, -73.9611371)  BRIGHTON 6 STREET
# 1837348  (40.8012354, -73.9418153)  EAST 119 STREET
# 1837349  (40.7747112, -73.9333863)  27 AVENUE
# 1837350  (40.6450318, -73.9199775)  RALPH AVENUE
# 1837352  (40.7199104, -73.8090389)  PARSONS BOULEVARD
#
#                         CROSS STREET NAME  NUMBER OF PERSONS INJURED  ...  \
# 13                         CONCORD STREET                        0.0  ...
# 17                               AVENUE K                        1.0  ...
# 18                        HYLAN BOULEVARD                        7.0  ...
# 25                        LONGWOOD AVENUE                        0.0  ...
# 28                           ROPES AVENUE                        2.0  ...
# ...                                   ...                        ...  ...
# 1837347  BRIGHTWATER COURT                                       0.0  ...
# 1837348  PARK AVENUE                                             0.0  ...
# 1837349  4 STREET                                                2.0  ...
# 1837350  CLARENDON ROAD                                          0.0  ...
# 1837352  UNION TURNPIKE                                          0.0  ...
#
#          NUMBER OF CYCLIST INJURED  NUMBER OF CYCLIST KILLED  \
# 13                               0                         0
# 17                               0                         0
# 18                               0                         0
# 25                               0                         0
# 28                               0                         0
# ...                            ...                       ...
# 1837347                          0                         0
# 1837348                          0                         0
# 1837349                          0                         0
# 1837350                          0                         0
# 1837352                          0                         0
#
#          NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED  \
# 13                                0                          0
# 17                                1                          0
# 18                                7                          0
# 25                                0                          0
# 28                                2                          0
# ...                             ...                        ...
# 1837347                           0                          0
# 1837348                           0                          0
# 1837349                           2                          0
# 1837350                           0                          0
# 1837352                           0                          0
#
#           CONTRIBUTING FACTOR VEHICLE 1  CONTRIBUTING FACTOR VEHICLE 2  \
# 13       Passing or Lane Usage Improper                    Unspecified
# 17                  Driver Inexperience                    Unspecified
# 18        Failure to Yield Right-of-Way                   Unsafe Speed
# 25                          Unspecified                    Unspecified
# 28                         Unsafe Speed                    Unspecified
# ...                                 ...                            ...
# 1837347                     Unspecified                    Unspecified
# 1837348                     Unspecified                    Unspecified
# 1837349   Failure to Yield Right-of-Way                    Unspecified
# 1837350                     Unspecified                    Unspecified
# 1837352  Driver Inattention/Distraction                    Unspecified
#
#          COLLISION_ID                  VEHICLE TYPE CODE 1  \
# 13            4136992                                 �MBU
# 17            4403773                                Sedan
# 18            4405244  Station Wagon/Sport Utility Vehicle
# 25            4407900                                Sedan
# 28            4408143  Station Wagon/Sport Utility Vehicle
# ...               ...                                  ...
# 1837347        113584                    PASSENGER VEHICLE
# 1837348         59654        SPORT UTILITY / STATION WAGON
# 1837349        272592                    PASSENGER VEHICLE
# 1837350        135041              SMALL COM VEH(4 TIRES)
# 1837352        233172                              UNKNOWN
#
#                          VEHICLE TYPE CODE 2  POPULATION
# 13                                      Taxi     4970026
# 17                                     Sedan     4970026
# 18       Station Wagon/Sport Utility Vehicle      912458
# 25                                     Sedan     2717758
# 28       Station Wagon/Sport Utility Vehicle     2717758
# ...                                      ...         ...
# 1837347                    PASSENGER VEHICLE     4970026
# 1837348                    PASSENGER VEHICLE     3123068
# 1837349        SPORT UTILITY / STATION WAGON     4460101
# 1837350                    PASSENGER VEHICLE     4970026
# 1837352                    PASSENGER VEHICLE     4460101
#
# [828356 rows x 23 columns]

# %% [markdown]
# # Create DimCollision Table

# %%
dim_collision = create_dimension(clean_collision_df,
                         ['COLLISION_ID'],
                         'ID',
                         1)
# Out:
# -----
#  creating dimension: COLLISION_ID_dim
# dimension COLLISION_ID_dim created with 828356 rows
# -----

# %%
dim_collision
# Out:
#              ID  COLLISION_ID
# 13            1       4136992
# 17            2       4403773
# 18            3       4405244
# 25            4       4407900
# 28            5       4408143
# ...         ...           ...
# 1837347  828352        113584
# 1837348  828353         59654
# 1837349  828354        272592
# 1837350  828355        135041
# 1837352  828356        233172
#
# [828356 rows x 2 columns]

# %% [markdown]
# # Create DimLocation Table

# %%
dim_location = create_dimension(clean_collision_df,
                         ['LOCATION','LATITUDE','LONGITUDE','ZIP CODE','BOROUGH','POPULATION','COLLISION_ID'],
                         'LOCATION_ID',
                         10000)
# Out:
# -----
#  creating dimension: LOCATION_dim
# dimension LOCATION_dim created with 68986 rows
# -----

# %%
dim_location['ZIP CODE'] = dim_location['ZIP CODE'].astype(str)

# %%
dim_location = dim_location.rename(columns={"ZIP CODE":"ZIP_CODE"})

# %%
dim_location
# Out:
#          LOCATION_ID                   LOCATION   LATITUDE  LONGITUDE  \
# 13             10000      (40.69754, -73.98312)  40.697540 -73.983120
# 17             10001       (40.626457, -73.918)  40.626457 -73.918000
# 18             10002     (40.526894, -74.16728)  40.526894 -74.167280
# 25             10003        (40.815, -73.89402)  40.815000 -73.894020
# 28             10004    (40.890076, -73.819855)  40.890076 -73.819855
# ...              ...                        ...        ...        ...
# 1836390        78981  (40.8138322, -73.8936336)  40.813832 -73.893634
# 1836522        78982  (40.5854402, -74.1484498)  40.585440 -74.148450
# 1836523        78983   (40.558305, -74.1645302)  40.558305 -74.164530
# 1836922        78984  (40.5882381, -73.9222706)  40.588238 -73.922271
# 1836992        78985  (40.5241475, -74.2135196)  40.524147 -74.213520
#
#         ZIP_CODE        BOROUGH  POPULATION  COLLISION_ID
# 13       11201.0       BROOKLYN     4970026       4136992
# 17       11234.0       BROOKLYN     4970026       4403773
# 18       10312.0  STATEN ISLAND      912458       4405244
# 25       10474.0          BRONX     2717758       4407900
# 28       10475.0          BRONX     2717758       4408143
# ...          ...            ...         ...           ...
# 1836390  10474.0          BRONX     2717758         76226
# 1836522  10314.0  STATEN ISLAND      912458        293244
# 1836523  10312.0  STATEN ISLAND      912458        293191
# 1836922  11229.0       BROOKLYN     4970026        116333
# 1836992  10309.0  STATEN ISLAND      912458        301280
#
# [68986 rows x 8 columns]

# %% [markdown]
# # Extract & Analyze Vehicle Data

# %%
vehicle_df = extract_CSV('Motor_Vehicle_Collisions_-_Vehicles.csv')
# Out:
# -----
#  extracting data from CSV
# C:\Users\Kven\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.
# 3683400 rows extracted
# -----

# %%
#sample_data_profiling(vehicle_df, 'Vehicle Data')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
#detailed_data_profiling(vehicle_df, 'Vehicle Data')
# Out:
# ==========
# Vehicle Data -- data profiling:
# number of rows 3683400
# number of columns 25
# -----
# column names: Index(['UNIQUE_ID', 'COLLISION_ID', 'CRASH_DATE', 'CRASH_TIME', 'VEHICLE_ID',
#        'STATE_REGISTRATION', 'VEHICLE_TYPE', 'VEHICLE_MAKE', 'VEHICLE_MODEL',
#        'VEHICLE_YEAR', 'TRAVEL_DIRECTION', 'VEHICLE_OCCUPANTS', 'DRIVER_SEX',
#        'DRIVER_LICENSE_STATUS', 'DRIVER_LICENSE_JURISDICTION', 'PRE_CRASH',
#        'POINT_OF_IMPACT', 'VEHICLE_DAMAGE', 'VEHICLE_DAMAGE_1',
#        'VEHICLE_DAMAGE_2', 'VEHICLE_DAMAGE_3', 'PUBLIC_PROPERTY_DAMAGE',
#        'PUBLIC_PROPERTY_DAMAGE_TYPE', 'CONTRIBUTING_FACTOR_1',
#        'CONTRIBUTING_FACTOR_2'],
#       dtype='object')
# -----
# column data types:
# UNIQUE_ID -- dtype: int64
# COLLISION_ID -- dtype: int64
# CRASH_DATE -- dtype: object
# CRASH_TIME -- dtype: object
# VEHICLE_ID -- dtype: object
# STATE_REGISTRATION -- dtype: object
# VEHICLE_TYPE -- dtype: object
# VEHICLE_MAKE -- dtype: object
# VEHICLE_MODEL -- dtype: object
# VEHICLE_YEAR -- dtype: float64
# TRAVEL_DIRECTION -- dtype: object
# VEHICLE_OCCUPANTS -- dtype: float64
# DRIVER_SEX -- dtype: object
# DRIVER_LICENSE_STATUS -- dtype: object
# DRIVER_LICENSE_JURISDICTION -- dtype: object
# PRE_CRASH -- dtype: object
# POINT_OF_IMPACT -- dtype: object
# VEHICLE_DAMAGE -- dtype: object
# VEHICLE_DAMAGE_1 -- dtype: object
# VEHICLE_DAMAGE_2 -- dtype: object
# VEHICLE_DAMAGE_3 -- dtype: object
# PUBLIC_PROPERTY_DAMAGE -- dtype: object
# PUBLIC_PROPERTY_DAMAGE_TYPE -- dtype: object
# CONTRIBUTING_FACTOR_1 -- dtype: object
# CONTRIBUTING_FACTOR_2 -- dtype: object
# -----
# Columns with null values:
# UNIQUE_ID                            0
# COLLISION_ID                         0
# CRASH_DATE                           0
# CRASH_TIME                           0
# VEHICLE_ID                           0
# STATE_REGISTRATION              213250
# VEHICLE_TYPE                    175150
# VEHICLE_MAKE                   1781378
# VEHICLE_MODEL                  3632026
# VEHICLE_YEAR                   1792529
# TRAVEL_DIRECTION               1632871
# VEHICLE_OCCUPANTS              1715456
# DRIVER_SEX                     2042634
# DRIVER_LICENSE_STATUS          2109561
# DRIVER_LICENSE_JURISDICTION    2101705
# PRE_CRASH                       880815
# POINT_OF_IMPACT                1660133
# VEHICLE_DAMAGE                 1676791
# VEHICLE_DAMAGE_1               2408656
# VEHICLE_DAMAGE_2               2735382
# VEHICLE_DAMAGE_3               2962706
# PUBLIC_PROPERTY_DAMAGE         1528863
# PUBLIC_PROPERTY_DAMAGE_TYPE    3664366
# CONTRIBUTING_FACTOR_1           116432
# CONTRIBUTING_FACTOR_2          1649017
# dtype: int64
# -----
# the percentage of nulls in every column:
# UNIQUE_ID                       0.000000
# COLLISION_ID                    0.000000
# CRASH_DATE                      0.000000
# CRASH_TIME                      0.000000
# VEHICLE_ID                      0.000000
# STATE_REGISTRATION              5.789488
# VEHICLE_TYPE                    4.755118
# VEHICLE_MAKE                   48.362328
# VEHICLE_MODEL                  98.605256
# VEHICLE_YEAR                   48.665065
# TRAVEL_DIRECTION               44.330537
# VEHICLE_OCCUPANTS              46.572623
# DRIVER_SEX                     55.455123
# DRIVER_LICENSE_STATUS          57.272113
# DRIVER_LICENSE_JURISDICTION    57.058832
# PRE_CRASH                      23.913097
# POINT_OF_IMPACT                45.070668
# VEHICLE_DAMAGE                 45.522914
# VEHICLE_DAMAGE_1               65.392192
# VEHICLE_DAMAGE_2               74.262421
# VEHICLE_DAMAGE_3               80.434001
# PUBLIC_PROPERTY_DAMAGE         41.506842
# PUBLIC_PROPERTY_DAMAGE_TYPE    99.483249
# CONTRIBUTING_FACTOR_1           3.160993
# CONTRIBUTING_FACTOR_2          44.768882
# dtype: float64
# -----
# number of duplicate rows:
# 0
# -----
# numeric column statistics:
#           UNIQUE_ID  COLLISION_ID  VEHICLE_YEAR  VEHICLE_OCCUPANTS
# count  3.683400e+06  3.683400e+06  1.890871e+06       1.967944e+06
# mean   1.603776e+07  2.988207e+06  2.014800e+03       1.019652e+03
# std    3.239644e+06  1.495392e+06  1.556035e+02       9.991264e+05
# min    1.117110e+05  2.200000e+01  1.000000e+03       0.000000e+00
# 25%    1.420989e+07  2.998459e+06  2.008000e+03       1.000000e+00
# 50%    1.729543e+07  3.561780e+06  2.013000e+03       1.000000e+00
# 75%    1.872298e+07  4.019685e+06  2.016000e+03       1.000000e+00
# max    2.009909e+07  4.473929e+06  2.006300e+04       1.000000e+09
# ==========

# %% [markdown]
# # Cleaning Vehicle Data

# %%
pure_vehicle_df = drop_unused_columns(vehicle_df,['UNIQUE_ID','CRASH_DATE','CRASH_TIME','STATE_REGISTRATION','VEHICLE_MODEL','VEHICLE_YEAR','TRAVEL_DIRECTION','DRIVER_SEX','DRIVER_LICENSE_STATUS','DRIVER_LICENSE_JURISDICTION','PRE_CRASH','VEHICLE_DAMAGE_1','VEHICLE_DAMAGE_2','VEHICLE_DAMAGE_3','PUBLIC_PROPERTY_DAMAGE','PUBLIC_PROPERTY_DAMAGE_TYPE','CONTRIBUTING_FACTOR_2'])

# %%
pure_vehicle_df
# Out:
#          COLLISION_ID                            VEHICLE_ID  \
# 0              100201                                     1
# 1             4213082  0553ab4d-9500-4cba-8d98-f4d7f89d5856
# 2             3307608                                     2
# 3             3308693                                     1
# 4              297666                                     1
# ...               ...                                   ...
# 3683395       4473887  91295ba4-8ce9-49fc-86e4-942c1c4bfef2
# 3683396       4473169  50e6b948-35d0-4140-b49d-449891e05130
# 3683397       4473377  02da5e75-e9c6-41b5-a469-d421b4dcc134
# 3683398       4473596  d05e0cdf-69e6-4803-afe4-df7f12d12521
# 3683399       4473898  c09582ea-fd26-463a-87bf-e4935539fb72
#
#                                 VEHICLE_TYPE   VEHICLE_MAKE  \
# 0                          PASSENGER VEHICLE            NaN
# 1        Station Wagon/Sport Utility Vehicle  TOYT -CAR/SUV
# 2                                       TAXI            NaN
# 3                          PASSENGER VEHICLE            NaN
# 4                          PASSENGER VEHICLE            NaN
# ...                                      ...            ...
# 3683395                                  Bus            NaN
# 3683396  Station Wagon/Sport Utility Vehicle  TOYT -CAR/SUV
# 3683397  Station Wagon/Sport Utility Vehicle  JEEP -CAR/SUV
# 3683398  Station Wagon/Sport Utility Vehicle  MAZD -CAR/SUV
# 3683399                                Sedan  TOYT -CAR/SUV
#
#          VEHICLE_OCCUPANTS          POINT_OF_IMPACT            VEHICLE_DAMAGE  \
# 0                      NaN                      NaN                       NaN
# 1                      1.0        Left Front Bumper  Left Front Quarter Panel
# 2                      NaN                      NaN                       NaN
# 3                      NaN                      NaN                       NaN
# 4                      NaN                      NaN                       NaN
# ...                    ...                      ...                       ...
# 3683395                NaN                      NaN                       NaN
# 3683396                1.0          Center Back End           Center Back End
# 3683397                0.0  Left Rear Quarter Panel   Left Rear Quarter Panel
# 3683398                1.0        Left Front Bumper         Left Front Bumper
# 3683399                1.0         Left Rear Bumper          Left Rear Bumper
#
#                   CONTRIBUTING_FACTOR_1
# 0                           Unspecified
# 1        Driver Inattention/Distraction
# 2        Driver Inattention/Distraction
# 3                           Unspecified
# 4                       Other Vehicular
# ...                                 ...
# 3683395             Passing Too Closely
# 3683396                     Unspecified
# 3683397                     Unspecified
# 3683398             Driver Inexperience
# 3683399                     Unspecified
#
# [3683400 rows x 8 columns]

# %%
clean_vehicle_df = perform_data_cleansing(pure_vehicle_df,
                               'Clean Collision Data',
                               null_values_approach = "drop",
                               duplicates_approach = "keep_first",
                               outliers_approach = 3,
                               outlier_columns = None)
# Out:
# ==========
# cleaning Clean Collision Data
# -----
# Clean Collision Data Null values cleaning method: drop
# dropping 1827075 Null rows
# -----
# Clean Collision Data duplicate values cleaning method: keep_first
# dropping 0 duplicate rows
# ==========

# %%
clean_vehicle_df
# Out:
#          COLLISION_ID                            VEHICLE_ID  \
# 1             4213082  0553ab4d-9500-4cba-8d98-f4d7f89d5856
# 5             3434155                                219456
# 6             4229067  c53b43d9-419a-4ab1-9361-3f2979078d89
# 7             3503027                                672828
# 10            3487936                                554272
# ...               ...                                   ...
# 3683394       4473863  40435077-2168-4b89-a6ee-803c81e4cef6
# 3683396       4473169  50e6b948-35d0-4140-b49d-449891e05130
# 3683397       4473377  02da5e75-e9c6-41b5-a469-d421b4dcc134
# 3683398       4473596  d05e0cdf-69e6-4803-afe4-df7f12d12521
# 3683399       4473898  c09582ea-fd26-463a-87bf-e4935539fb72
#
#                                 VEHICLE_TYPE    VEHICLE_MAKE  \
# 1        Station Wagon/Sport Utility Vehicle   TOYT -CAR/SUV
# 5                                 4 dr sedan   MERZ -CAR/SUV
# 6                                        Bus  FRHT-TRUCK/BUS
# 7        Station Wagon/Sport Utility Vehicle   FORD -CAR/SUV
# 10                               Convertible   VOLK -CAR/SUV
# ...                                      ...             ...
# 3683394                                Sedan   CHRY -CAR/SUV
# 3683396  Station Wagon/Sport Utility Vehicle   TOYT -CAR/SUV
# 3683397  Station Wagon/Sport Utility Vehicle   JEEP -CAR/SUV
# 3683398  Station Wagon/Sport Utility Vehicle   MAZD -CAR/SUV
# 3683399                                Sedan   TOYT -CAR/SUV
#
#          VEHICLE_OCCUPANTS           POINT_OF_IMPACT  \
# 1                      1.0         Left Front Bumper
# 5                      2.0        Right Front Bumper
# 6                     13.0  Left Front Quarter Panel
# 7                      2.0          Center Front End
# 10                     1.0         Right Rear Bumper
# ...                    ...                       ...
# 3683394                1.0        Right Front Bumper
# 3683396                1.0           Center Back End
# 3683397                0.0   Left Rear Quarter Panel
# 3683398                1.0         Left Front Bumper
# 3683399                1.0          Left Rear Bumper
#
#                    VEHICLE_DAMAGE           CONTRIBUTING_FACTOR_1
# 1        Left Front Quarter Panel  Driver Inattention/Distraction
# 5              Right Front Bumper  Driver Inattention/Distraction
# 6        Left Front Quarter Panel                     Unspecified
# 7                Center Front End  Driver Inattention/Distraction
# 10              Right Rear Bumper                     Unspecified
# ...                           ...                             ...
# 3683394        Right Front Bumper                     Unspecified
# 3683396           Center Back End                     Unspecified
# 3683397   Left Rear Quarter Panel                     Unspecified
# 3683398         Left Front Bumper             Driver Inexperience
# 3683399          Left Rear Bumper                     Unspecified
#
# [1856325 rows x 8 columns]

# %% [markdown]
# # Create DimVehicle Table

# %%
dim_vehicle = create_dimension(clean_vehicle_df,
                         ['VEHICLE_ID','VEHICLE_TYPE','VEHICLE_MAKE','COLLISION_ID'],
                         'ID',
                         7000)
# Out:
# -----
#  creating dimension: VEHICLE_ID_dim
# dimension VEHICLE_ID_dim created with 1856325 rows
# -----

# %%
dim_vehicle
# Out:
#               ID                            VEHICLE_ID  \
# 1           7000  0553ab4d-9500-4cba-8d98-f4d7f89d5856
# 5           7001                                219456
# 6           7002  c53b43d9-419a-4ab1-9361-3f2979078d89
# 7           7003                                672828
# 10          7004                                554272
# ...          ...                                   ...
# 3683394  1863320  40435077-2168-4b89-a6ee-803c81e4cef6
# 3683396  1863321  50e6b948-35d0-4140-b49d-449891e05130
# 3683397  1863322  02da5e75-e9c6-41b5-a469-d421b4dcc134
# 3683398  1863323  d05e0cdf-69e6-4803-afe4-df7f12d12521
# 3683399  1863324  c09582ea-fd26-463a-87bf-e4935539fb72
#
#                                 VEHICLE_TYPE    VEHICLE_MAKE  COLLISION_ID
# 1        Station Wagon/Sport Utility Vehicle   TOYT -CAR/SUV       4213082
# 5                                 4 dr sedan   MERZ -CAR/SUV       3434155
# 6                                        Bus  FRHT-TRUCK/BUS       4229067
# 7        Station Wagon/Sport Utility Vehicle   FORD -CAR/SUV       3503027
# 10                               Convertible   VOLK -CAR/SUV       3487936
# ...                                      ...             ...           ...
# 3683394                                Sedan   CHRY -CAR/SUV       4473863
# 3683396  Station Wagon/Sport Utility Vehicle   TOYT -CAR/SUV       4473169
# 3683397  Station Wagon/Sport Utility Vehicle   JEEP -CAR/SUV       4473377
# 3683398  Station Wagon/Sport Utility Vehicle   MAZD -CAR/SUV       4473596
# 3683399                                Sedan   TOYT -CAR/SUV       4473898
#
# [1856325 rows x 5 columns]

# %% [markdown]
# # Create DimFactors Table

# %%
dim_factors = create_dimension(clean_vehicle_df,
                         ['COLLISION_ID','CONTRIBUTING_FACTOR_1'],
                         'FACTOR_ID',
                         15000)
# Out:
# -----
#  creating dimension: COLLISION_ID_dim
# dimension COLLISION_ID_dim created with 1037795 rows
# -----

# %%
dim_factors
# Out:
#          FACTOR_ID  COLLISION_ID           CONTRIBUTING_FACTOR_1
# 1            15000       4213082  Driver Inattention/Distraction
# 5            15001       3434155  Driver Inattention/Distraction
# 6            15002       4229067                     Unspecified
# 7            15003       3503027  Driver Inattention/Distraction
# 10           15004       3487936                     Unspecified
# ...            ...           ...                             ...
# 3683379    1052790       4473303              Turning Improperly
# 3683381    1052791       4473157                     Unspecified
# 3683390    1052792       4473333                     Unspecified
# 3683392    1052793       4473912                     Unspecified
# 3683393    1052794       4473596  Driver Inattention/Distraction
#
# [1037795 rows x 3 columns]

# %% [markdown]
# # Create DimDate Table

# %%
dim_date = clean_collision_df[['CRASH_DATE','CRASH_TIME','COLLISION_ID']]

# %%
dim_date['CRASH_DATE'] = pd.to_datetime(dim_date['CRASH_DATE'], format='%m/%d/%Y')
# Out:
# C:\Users\Kven\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dim_date['HOURLY_INTERVAL'] = pd.DatetimeIndex(dim_date['CRASH_TIME']).hour
dim_date['DAY'] = pd.DatetimeIndex(dim_date['CRASH_DATE']).day
dim_date['WEEK'] = pd.DatetimeIndex(dim_date['CRASH_DATE']).week
dim_date['MONTH'] = pd.DatetimeIndex(dim_date['CRASH_DATE']).month
dim_date['YEAR'] = pd.DatetimeIndex(dim_date['CRASH_DATE']).year
# Out:
# C:\Users\Kven\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Kven\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Kven\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Kven\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Kven\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Kven\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
dim_date
# Out:
#         CRASH_DATE CRASH_TIME  COLLISION_ID  HOURLY_INTERVAL  DAY  WEEK  \
# 13      2019-05-21      22:50       4136992               22   21    21
# 17      2021-03-31      22:20       4403773               22   31    13
# 18      2021-04-06      22:58       4405244               22    6    14
# 25      2021-04-16      17:40       4407900               17   16    15
# 28      2021-04-16      16:35       4408143               16   16    15
# ...            ...        ...           ...              ...  ...   ...
# 1837347 2012-07-07      17:35        113584               17    7    27
# 1837348 2012-07-06      15:09         59654               15    6    27
# 1837349 2012-07-03      17:30        272592               17    3    27
# 1837350 2012-07-01      15:30        135041               15    1    26
# 1837352 2012-07-05      23:00        233172               23    5    27
#
#          MONTH  YEAR
# 13           5  2019
# 17           3  2021
# 18           4  2021
# 25           4  2021
# 28           4  2021
# ...        ...   ...
# 1837347      7  2012
# 1837348      7  2012
# 1837349      7  2012
# 1837350      7  2012
# 1837352      7  2012
#
# [828356 rows x 8 columns]

# %% [markdown]
# # Create Person Facts Table

# %%
dim_person.head(3)
# Out:
#      ID                             PERSON_ID  PERSON_AGE PERSON_SEX  \
# 1  1000  4629e500-a73e-48dc-b8fb-53124d124b80        33.0          F
# 4  1001  e038e18f-40fb-4471-99cf-345eae36e064         7.0          F
# 5  1002  84bcb3a7-d201-4c61-9e30-fe29268c1074        27.0          M
#
#   PERSON_TYPE PERSON_INJURY   BODILY_INJURY  \
# 1    Occupant   Unspecified  Does Not Apply
# 4    Occupant   Unspecified  Does Not Apply
# 5    Occupant       Injured            Back
#
#                                  POSITION_IN_VEHICLE   PED_ROLE  COLLISION_ID
# 1  Front passenger, if two or more persons, inclu...  Passenger       4230587
# 4  Right rear passenger or motorcycle sidecar pas...  Passenger       4231168
# 5                                             Driver     Driver       4230743

# %%
dim_collision.head(3)
# Out:
#     ID  COLLISION_ID
# 13   1       4136992
# 17   2       4403773
# 18   3       4405244

# %%
dim_vehicle.head(3)
# Out:
#      ID                            VEHICLE_ID  \
# 1  7000  0553ab4d-9500-4cba-8d98-f4d7f89d5856
# 5  7001                                219456
# 6  7002  c53b43d9-419a-4ab1-9361-3f2979078d89
#
#                           VEHICLE_TYPE    VEHICLE_MAKE  COLLISION_ID
# 1  Station Wagon/Sport Utility Vehicle   TOYT -CAR/SUV       4213082
# 5                           4 dr sedan   MERZ -CAR/SUV       3434155
# 6                                  Bus  FRHT-TRUCK/BUS       4229067

# %%
dim_date.head(3)
# Out:
#    CRASH_DATE CRASH_TIME  COLLISION_ID  HOURLY_INTERVAL  DAY  WEEK  MONTH  \
# 13 2019-05-21      22:50       4136992               22   21    21      5
# 17 2021-03-31      22:20       4403773               22   31    13      3
# 18 2021-04-06      22:58       4405244               22    6    14      4
#
#     YEAR
# 13  2019
# 17  2021
# 18  2021

# %%
fact_person = clean_person_df.copy()

# %%
fact_person_merged_vehicle = fact_person.merge(dim_vehicle,on=['COLLISION_ID'],how='inner')

# %%
fact_person_merged_vehicle_merged_date = pd.concat([dim_date,fact_person_merged_vehicle])

# %%
fact_person_merged_vehicle_merged_date_merged_person = fact_person_merged_vehicle_merged_date.merge(dim_person,on=['PERSON_ID'],how='inner')

# %%
fact_person_merged_vehicle_merged_date_merged_person.drop_duplicates(subset ="PERSON_ID",
                     keep = 'first', inplace = True)

# %%
fact_person_merged_vehicle_merged_date_merged_person
# Out:
#          CRASH_DATE CRASH_TIME  COLLISION_ID_x  HOURLY_INTERVAL  DAY  WEEK  \
# 0        10/25/2019        NaN         4230587              NaN  NaN   NaN
# 2        10/25/2019        NaN         4230587              NaN  NaN   NaN
# 4        10/25/2019        NaN         4230587              NaN  NaN   NaN
# 6        10/25/2019        NaN         4230587              NaN  NaN   NaN
# 8        10/25/2019        NaN         4231168              NaN  NaN   NaN
# ...             ...        ...             ...              ...  ...   ...
# 4444236  10/14/2021        NaN         4467017              NaN  NaN   NaN
# 4444237  10/29/2021        NaN         4472318              NaN  NaN   NaN
# 4444239  10/29/2021        NaN         4472318              NaN  NaN   NaN
# 4444241  10/08/2021        NaN         4465408              NaN  NaN   NaN
# 4444242  10/25/2021        NaN         4470577              NaN  NaN   NaN
#
#          MONTH  YEAR                             PERSON_ID PERSON_TYPE_x  ...  \
# 0          NaN   NaN  4629e500-a73e-48dc-b8fb-53124d124b80      Occupant  ...
# 2          NaN   NaN  cd27406c-5cc1-4a3c-9636-3e0385b0b307      Occupant  ...
# 4          NaN   NaN  47e9fb58-1df7-46cc-a2ff-9c2deb0f3e54      Occupant  ...
# 6          NaN   NaN  86cd7a22-51be-47ed-9e2c-9f3278c043e7      Occupant  ...
# 8          NaN   NaN  e038e18f-40fb-4471-99cf-345eae36e064      Occupant  ...
# ...        ...   ...                                   ...           ...  ...
# 4444236    NaN   NaN  78693e36-e331-4e8e-bd42-609130760f3c      Occupant  ...
# 4444237    NaN   NaN  1b95c74c-1fb9-45c8-af31-7d43f6b49124      Occupant  ...
# 4444239    NaN   NaN  fa7e2da5-4dbd-4cc2-bcf7-9a0729ab89aa      Occupant  ...
# 4444241    NaN   NaN  b996eae8-5520-48a8-ae7e-7b0dca688922      Occupant  ...
# 4444242    NaN   NaN  442aaa25-d134-40c3-a0cb-3718205fd6f0      Occupant  ...
#
#           VEHICLE_MAKE     ID_y PERSON_AGE_y PERSON_SEX_y PERSON_TYPE_y  \
# 0        NISS -CAR/SUV     1000         33.0            F      Occupant
# 2        NISS -CAR/SUV     1654          6.0            M      Occupant
# 4        NISS -CAR/SUV     1790         33.0            M      Occupant
# 6        NISS -CAR/SUV     2198         82.0            M      Occupant
# 8        TOYT -CAR/SUV     1001          7.0            F      Occupant
# ...                ...      ...          ...          ...           ...
# 4444236  AUDI -CAR/SUV  2268250         31.0            M      Occupant
# 4444237  NISS -CAR/SUV  2268374         51.0            F      Occupant
# 4444239  NISS -CAR/SUV  2268510         42.0            M      Occupant
# 4444241  HOND -CAR/SUV  2268455         30.0            F      Occupant
# 4444242  TOYT -CAR/SUV  2268470         35.0            F      Occupant
#
#         PERSON_INJURY_y  BODILY_INJURY_y  \
# 0           Unspecified   Does Not Apply
# 2           Unspecified   Does Not Apply
# 4           Unspecified   Does Not Apply
# 6           Unspecified   Does Not Apply
# 8           Unspecified   Does Not Apply
# ...                 ...              ...
# 4444236     Unspecified   Does Not Apply
# 4444237     Unspecified   Does Not Apply
# 4444239         Injured      Entire Body
# 4444241         Injured             Neck
# 4444242         Injured      Entire Body
#
#                                      POSITION_IN_VEHICLE_y PED_ROLE_y  \
# 0        Front passenger, if two or more persons, inclu...  Passenger
# 2        Right rear passenger or motorcycle sidecar pas...  Passenger
# 4                                                   Driver     Driver
# 6                                                   Driver     Driver
# 8        Right rear passenger or motorcycle sidecar pas...  Passenger
# ...                                                    ...        ...
# 4444236                                             Driver     Driver
# 4444237                                             Driver     Driver
# 4444239  Front passenger, if two or more persons, inclu...  Passenger
# 4444241                                             Driver     Driver
# 4444242                                             Driver     Driver
#
#         COLLISION_ID_y
# 0              4230587
# 2              4230587
# 4              4230587
# 6              4230587
# 8              4231168
# ...                ...
# 4444236        4467017
# 4444237        4472318
# 4444239        4472318
# 4444241        4465408
# 4444242        4470577
#
# [2247010 rows x 29 columns]

# %%
person_facts = drop_unused_columns(fact_person_merged_vehicle_merged_date_merged_person,['PERSON_TYPE_x','PERSON_INJURY_x','PERSON_AGE_x','BODILY_INJURY_x','POSITION_IN_VEHICLE_x','PED_ROLE_x','PERSON_SEX_x','COLLISION_ID_y','ID_x','VEHICLE_TYPE','VEHICLE_MAKE','CRASH_TIME','HOURLY_INTERVAL','DAY','WEEK','MONTH','YEAR','ID_y','PERSON_AGE_y','PERSON_SEX_y','PERSON_TYPE_y','PERSON_INJURY_y','BODILY_INJURY_y','POSITION_IN_VEHICLE_y','PED_ROLE_y'])

# %%
person_facts.drop_duplicates(keep='first')
# Out:
#          CRASH_DATE  COLLISION_ID_x                             PERSON_ID  \
# 0        10/25/2019         4230587  4629e500-a73e-48dc-b8fb-53124d124b80
# 2        10/25/2019         4230587  cd27406c-5cc1-4a3c-9636-3e0385b0b307
# 4        10/25/2019         4230587  47e9fb58-1df7-46cc-a2ff-9c2deb0f3e54
# 6        10/25/2019         4230587  86cd7a22-51be-47ed-9e2c-9f3278c043e7
# 8        10/25/2019         4231168  e038e18f-40fb-4471-99cf-345eae36e064
# ...             ...             ...                                   ...
# 4444236  10/14/2021         4467017  78693e36-e331-4e8e-bd42-609130760f3c
# 4444237  10/29/2021         4472318  1b95c74c-1fb9-45c8-af31-7d43f6b49124
# 4444239  10/29/2021         4472318  fa7e2da5-4dbd-4cc2-bcf7-9a0729ab89aa
# 4444241  10/08/2021         4465408  b996eae8-5520-48a8-ae7e-7b0dca688922
# 4444242  10/25/2021         4470577  442aaa25-d134-40c3-a0cb-3718205fd6f0
#
#                                    VEHICLE_ID
# 0        37080180-400c-431e-90eb-c09d736fd95e
# 2        37080180-400c-431e-90eb-c09d736fd95e
# 4        37080180-400c-431e-90eb-c09d736fd95e
# 6        37080180-400c-431e-90eb-c09d736fd95e
# 8        280b021d-1f42-4267-9e96-48808086a209
# ...                                       ...
# 4444236  d11b7f43-0f87-4495-b47f-ede64a30bf4d
# 4444237  a49519d1-5f83-4dd9-ad8b-e3afda7b1897
# 4444239  a49519d1-5f83-4dd9-ad8b-e3afda7b1897
# 4444241  0bd5e373-90ad-470f-8f85-fd1d42b1f955
# 4444242  6d5d0c42-f378-4084-b554-24cb0e07d824
#
# [2247010 rows x 4 columns]

# %% [markdown]
# # Create Crash Facts Table

# %%
dim_collision.head(3)
# Out:
#     ID  COLLISION_ID
# 13   1       4136992
# 17   2       4403773
# 18   3       4405244

# %%
dim_vehicle.head(3)
# Out:
#      ID                            VEHICLE_ID  \
# 1  7000  0553ab4d-9500-4cba-8d98-f4d7f89d5856
# 5  7001                                219456
# 6  7002  c53b43d9-419a-4ab1-9361-3f2979078d89
#
#                           VEHICLE_TYPE    VEHICLE_MAKE  COLLISION_ID
# 1  Station Wagon/Sport Utility Vehicle   TOYT -CAR/SUV       4213082
# 5                           4 dr sedan   MERZ -CAR/SUV       3434155
# 6                                  Bus  FRHT-TRUCK/BUS       4229067

# %%
dim_date.head(3)
# Out:
#    CRASH_DATE CRASH_TIME  COLLISION_ID  HOURLY_INTERVAL  DAY  WEEK  MONTH  \
# 13 2019-05-21      22:50       4136992               22   21    21      5
# 17 2021-03-31      22:20       4403773               22   31    13      3
# 18 2021-04-06      22:58       4405244               22    6    14      4
#
#     YEAR
# 13  2019
# 17  2021
# 18  2021

# %%
dim_location.head(3)
# Out:
#     LOCATION_ID                LOCATION   LATITUDE  LONGITUDE ZIP_CODE  \
# 13        10000   (40.69754, -73.98312)  40.697540  -73.98312  11201.0
# 17        10001    (40.626457, -73.918)  40.626457  -73.91800  11234.0
# 18        10002  (40.526894, -74.16728)  40.526894  -74.16728  10312.0
#
#           BOROUGH  POPULATION  COLLISION_ID
# 13       BROOKLYN     4970026       4136992
# 17       BROOKLYN     4970026       4403773
# 18  STATEN ISLAND      912458       4405244

# %%
fact_crash = clean_collision_df.copy()

# %%
fact_crash_merged_vehicle = fact_crash.merge(dim_vehicle, on=['COLLISION_ID'],how='inner')

# %%
fact_crash_merged_vehicle_merged_date = pd.concat([dim_date,fact_crash_merged_vehicle])

# %%
fact_crash_merged_vehicle_merged_date_merged_location = fact_crash_merged_vehicle_merged_date.merge(dim_location,on=['LOCATION'],how='inner')

# %%
fact_crash_merged_vehicle_merged_date_merged_location
# Out:
#         CRASH_DATE CRASH_TIME  COLLISION_ID_x  HOURLY_INTERVAL  DAY  WEEK  \
# 0       05/21/2019      22:50         4136992              NaN  NaN   NaN
# 1       05/21/2019      22:50         4136992              NaN  NaN   NaN
# 2       01/14/2021      17:10         4384098              NaN  NaN   NaN
# 3       01/14/2021      17:10         4384098              NaN  NaN   NaN
# 4       10/16/2021       0:36         4467540              NaN  NaN   NaN
# ...            ...        ...             ...              ...  ...   ...
# 635131  12/15/2015      10:45         3580632              NaN  NaN   NaN
# 635132  12/18/2014       9:15         3812222              NaN  NaN   NaN
# 635133  12/18/2014       9:15         3812222              NaN  NaN   NaN
# 635134  08/14/2014      11:30         3501088              NaN  NaN   NaN
# 635135  08/14/2014      11:30         3501088              NaN  NaN   NaN
#
#         MONTH  YEAR      BOROUGH_x ZIP CODE  ...  \
# 0         NaN   NaN       BROOKLYN  11201.0  ...
# 1         NaN   NaN       BROOKLYN  11201.0  ...
# 2         NaN   NaN       BROOKLYN  11201.0  ...
# 3         NaN   NaN       BROOKLYN  11201.0  ...
# 4         NaN   NaN       BROOKLYN  11201.0  ...
# ...       ...   ...            ...      ...  ...
# 635131    NaN   NaN  STATEN ISLAND  10304.0  ...
# 635132    NaN   NaN         QUEENS    11365  ...
# 635133    NaN   NaN         QUEENS    11365  ...
# 635134    NaN   NaN       BROOKLYN    11218  ...
# 635135    NaN   NaN       BROOKLYN    11218  ...
#
#                                   VEHICLE_ID       VEHICLE_TYPE  \
# 0       985541e4-3517-4547-824e-4360ecff37a6               AMBU
# 1       3b813680-8669-40ac-ad2f-5df148412212               Taxi
# 2       90722d72-d97f-44ce-9317-9b3205963769              Sedan
# 3       e8ea9784-a209-41ad-8634-aebc5306eb77          Ambulance
# 4       778de9ba-bc6d-4de0-90de-6617042aff76               Taxi
# ...                                      ...                ...
# 635131                               1206574              Sedan
# 635132  765c5b9c-3cfa-4d09-998f-3b22f378cf3b  Garbage or Refuse
# 635133  c0a8ed45-2778-4d58-80a6-53de7e2b01b2              Sedan
# 635134                                661979              Sedan
# 635135                                661980              Sedan
#
#           VEHICLE_MAKE LOCATION_ID LATITUDE_y  LONGITUDE_y  ZIP_CODE  \
# 0            AMBULANCE       10000  40.697540    -73.98312   11201.0
# 1        TOYT -CAR/SUV       10000  40.697540    -73.98312   11201.0
# 2        MERZ -CAR/SUV       10000  40.697540    -73.98312   11201.0
# 3       FORD-TRUCK/BUS       10000  40.697540    -73.98312   11201.0
# 4        NISS -CAR/SUV       10000  40.697540    -73.98312   11201.0
# ...                ...         ...        ...          ...       ...
# 635131   NISS -CAR/SUV       57633  40.846700    -73.91576   10304.0
# 635132            mack       72745  40.730526    -73.80144     11365
# 635133   MERZ -CAR/SUV       72745  40.730526    -73.80144     11365
# 635134    BMW -CAR/SUV       74144  40.642498    -73.96846     11218
# 635135   TOYT -CAR/SUV       74144  40.642498    -73.96846     11218
#
#             BOROUGH_y  POPULATION_y  COLLISION_ID_y
# 0            BROOKLYN       4970026         4136992
# 1            BROOKLYN       4970026         4136992
# 2            BROOKLYN       4970026         4136992
# 3            BROOKLYN       4970026         4136992
# 4            BROOKLYN       4970026         4136992
# ...               ...           ...             ...
# 635131  STATEN ISLAND        912458         3580632
# 635132         QUEENS       4460101         3812222
# 635133         QUEENS       4460101         3812222
# 635134       BROOKLYN       4970026         3501088
# 635135       BROOKLYN       4970026         3501088
#
# [635136 rows x 39 columns]

# %%
crash_facts = drop_unused_columns(fact_crash_merged_vehicle_merged_date_merged_location, ['BOROUGH_x', 'LATITUDE_x',
       'LONGITUDE_x', 'ON STREET NAME', 'CROSS STREET NAME',
       'NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED',
       'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED',
       'NUMBER OF CYCLIST INJURED', 'NUMBER OF CYCLIST KILLED',
       'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED',
       'CONTRIBUTING FACTOR VEHICLE 1', 'CONTRIBUTING FACTOR VEHICLE 2'
       ,'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
       'ID', 'VEHICLE_TYPE', 'VEHICLE_MAKE',
       'HOURLY_INTERVAL', 'DAY', 'WEEK',
       'MONTH', 'YEAR', 'LATITUDE_y', 'LONGITUDE_y',
       'BOROUGH_y', 'POPULATION_y', 'COLLISION_ID_y','ZIP CODE'])

# %%
crash_facts
# Out:
#         CRASH_DATE CRASH_TIME  COLLISION_ID_x                LOCATION  \
# 0       05/21/2019      22:50         4136992   (40.69754, -73.98312)
# 1       05/21/2019      22:50         4136992   (40.69754, -73.98312)
# 2       01/14/2021      17:10         4384098   (40.69754, -73.98312)
# 3       01/14/2021      17:10         4384098   (40.69754, -73.98312)
# 4       10/16/2021       0:36         4467540   (40.69754, -73.98312)
# ...            ...        ...             ...                     ...
# 635131  12/15/2015      10:45         3580632    (40.8467, -73.91576)
# 635132  12/18/2014       9:15         3812222  (40.730526, -73.80144)
# 635133  12/18/2014       9:15         3812222  (40.730526, -73.80144)
# 635134  08/14/2014      11:30         3501088  (40.642498, -73.96846)
# 635135  08/14/2014      11:30         3501088  (40.642498, -73.96846)
#
#         POPULATION_x                            VEHICLE_ID  LOCATION_ID  \
# 0          4970026.0  985541e4-3517-4547-824e-4360ecff37a6        10000
# 1          4970026.0  3b813680-8669-40ac-ad2f-5df148412212        10000
# 2          4970026.0  90722d72-d97f-44ce-9317-9b3205963769        10000
# 3          4970026.0  e8ea9784-a209-41ad-8634-aebc5306eb77        10000
# 4          4970026.0  778de9ba-bc6d-4de0-90de-6617042aff76        10000
# ...              ...                                   ...          ...
# 635131      912458.0                               1206574        57633
# 635132     4460101.0  765c5b9c-3cfa-4d09-998f-3b22f378cf3b        72745
# 635133     4460101.0  c0a8ed45-2778-4d58-80a6-53de7e2b01b2        72745
# 635134     4970026.0                                661979        74144
# 635135     4970026.0                                661980        74144
#
#        ZIP_CODE
# 0       11201.0
# 1       11201.0
# 2       11201.0
# 3       11201.0
# 4       11201.0
# ...         ...
# 635131  10304.0
# 635132    11365
# 635133    11365
# 635134    11218
# 635135    11218
#
# [635136 rows x 8 columns]

# %%
crash_facts.drop_duplicates(keep='first')
# Out:
#         CRASH_DATE CRASH_TIME  COLLISION_ID_x                LOCATION  \
# 0       05/21/2019      22:50         4136992   (40.69754, -73.98312)
# 1       05/21/2019      22:50         4136992   (40.69754, -73.98312)
# 2       01/14/2021      17:10         4384098   (40.69754, -73.98312)
# 3       01/14/2021      17:10         4384098   (40.69754, -73.98312)
# 4       10/16/2021       0:36         4467540   (40.69754, -73.98312)
# ...            ...        ...             ...                     ...
# 635131  12/15/2015      10:45         3580632    (40.8467, -73.91576)
# 635132  12/18/2014       9:15         3812222  (40.730526, -73.80144)
# 635133  12/18/2014       9:15         3812222  (40.730526, -73.80144)
# 635134  08/14/2014      11:30         3501088  (40.642498, -73.96846)
# 635135  08/14/2014      11:30         3501088  (40.642498, -73.96846)
#
#         POPULATION_x                            VEHICLE_ID  LOCATION_ID  \
# 0          4970026.0  985541e4-3517-4547-824e-4360ecff37a6        10000
# 1          4970026.0  3b813680-8669-40ac-ad2f-5df148412212        10000
# 2          4970026.0  90722d72-d97f-44ce-9317-9b3205963769        10000
# 3          4970026.0  e8ea9784-a209-41ad-8634-aebc5306eb77        10000
# 4          4970026.0  778de9ba-bc6d-4de0-90de-6617042aff76        10000
# ...              ...                                   ...          ...
# 635131      912458.0                               1206574        57633
# 635132     4460101.0  765c5b9c-3cfa-4d09-998f-3b22f378cf3b        72745
# 635133     4460101.0  c0a8ed45-2778-4d58-80a6-53de7e2b01b2        72745
# 635134     4970026.0                                661979        74144
# 635135     4970026.0                                661980        74144
#
#        ZIP_CODE
# 0       11201.0
# 1       11201.0
# 2       11201.0
# 3       11201.0
# 4       11201.0
# ...         ...
# 635131  10304.0
# 635132    11365
# 635133    11365
# 635134    11218
# 635135    11218
#
# [635136 rows x 8 columns]

# %% [markdown]
# # Create Vehicle Facts Table

# %%
dim_vehicle.head(3)
# Out:
#      ID                            VEHICLE_ID  \
# 1  7000  0553ab4d-9500-4cba-8d98-f4d7f89d5856
# 5  7001                                219456
# 6  7002  c53b43d9-419a-4ab1-9361-3f2979078d89
#
#                           VEHICLE_TYPE    VEHICLE_MAKE  COLLISION_ID
# 1  Station Wagon/Sport Utility Vehicle   TOYT -CAR/SUV       4213082
# 5                           4 dr sedan   MERZ -CAR/SUV       3434155
# 6                                  Bus  FRHT-TRUCK/BUS       4229067

# %%
dim_factors.head(3)
# Out:
#    FACTOR_ID  COLLISION_ID           CONTRIBUTING_FACTOR_1
# 1      15000       4213082  Driver Inattention/Distraction
# 5      15001       3434155  Driver Inattention/Distraction
# 6      15002       4229067                     Unspecified

# %%
dim_collision.head(3)
# Out:
#     ID  COLLISION_ID
# 13   1       4136992
# 17   2       4403773
# 18   3       4405244

# %%
dim_date.head(3)
# Out:
#    CRASH_DATE CRASH_TIME  COLLISION_ID  HOURLY_INTERVAL  DAY  WEEK  MONTH  \
# 13 2019-05-21      22:50       4136992               22   21    21      5
# 17 2021-03-31      22:20       4403773               22   31    13      3
# 18 2021-04-06      22:58       4405244               22    6    14      4
#
#     YEAR
# 13  2019
# 17  2021
# 18  2021

# %%
fact_vehicle = clean_vehicle_df.copy()

# %%
fact_vehicle_merged_vehicle = fact_vehicle.merge(dim_vehicle,on=['COLLISION_ID'],how='inner')

# %%
fact_vehicle_merged_vehicle_merged_date = fact_vehicle_merged_vehicle.merge(dim_date,on=['COLLISION_ID'],how='inner')

# %%
fact_vehicle_merged_vehicle_merged_date_merged_factor = fact_vehicle_merged_vehicle_merged_date.merge(dim_factors,on=['COLLISION_ID'],how='inner')

# %%
fact_vehicle_merged_vehicle_merged_date_merged_factor
# Out:
#          COLLISION_ID                          VEHICLE_ID_x VEHICLE_TYPE_x  \
# 0             3487936                                554272    Convertible
# 1             3487936                                554272    Convertible
# 2             3487936                                554271     4 dr sedan
# 3             3487936                                554271     4 dr sedan
# 4             3499697                                650962          Sedan
# ...               ...                                   ...            ...
# 1343321       4473641  b90ba5a8-ff19-458f-8d4c-fbb9b0ca5dee  Pick-up Truck
# 1343322       4473807  f0dc0d15-b301-408a-a6e2-338645cf2875          Sedan
# 1343323       4473807  f0dc0d15-b301-408a-a6e2-338645cf2875          Sedan
# 1343324       4473807  c98f0f0c-574c-483d-abe2-646fd8a4ce58            Bus
# 1343325       4473807  c98f0f0c-574c-483d-abe2-646fd8a4ce58            Bus
#
#         VEHICLE_MAKE_x  VEHICLE_OCCUPANTS     POINT_OF_IMPACT  \
# 0        VOLK -CAR/SUV                1.0   Right Rear Bumper
# 1        VOLK -CAR/SUV                1.0   Right Rear Bumper
# 2        HOND -CAR/SUV                1.0    Center Front End
# 3        HOND -CAR/SUV                1.0    Center Front End
# 4        NISS -CAR/SUV                2.0     Left Side Doors
# ...                ...                ...                 ...
# 1343321  DODG -CAR/SUV                1.0    Center Front End
# 1343322  HOND -CAR/SUV                1.0  Right Front Bumper
# 1343323  HOND -CAR/SUV                1.0  Right Front Bumper
# 1343324           Nova                1.0    Left Rear Bumper
# 1343325           Nova                1.0    Left Rear Bumper
#
#             VEHICLE_DAMAGE         CONTRIBUTING_FACTOR_1_x       ID  \
# 0        Right Rear Bumper                     Unspecified     7004
# 1        Right Rear Bumper                     Unspecified    80365
# 2         Center Front End  Driver Inattention/Distraction     7004
# 3         Center Front End  Driver Inattention/Distraction    80365
# 4          Left Side Doors                     Unspecified     7005
# ...                    ...                             ...      ...
# 1343321   Center Front End  Driver Inattention/Distraction  1863256
# 1343322   Center Front End              Turning Improperly  1863263
# 1343323   Center Front End              Turning Improperly  1863311
# 1343324   Left Rear Bumper                     Unspecified  1863263
# 1343325   Left Rear Bumper                     Unspecified  1863311
#
#                                  VEHICLE_ID_y  ... VEHICLE_MAKE_y CRASH_DATE  \
# 0                                      554272  ...  VOLK -CAR/SUV 2016-07-22
# 1                                      554271  ...  HOND -CAR/SUV 2016-07-22
# 2                                      554272  ...  VOLK -CAR/SUV 2016-07-22
# 3                                      554271  ...  HOND -CAR/SUV 2016-07-22
# 4                                      650962  ...  NISS -CAR/SUV 2016-08-13
# ...                                       ...  ...            ...        ...
# 1343321  b90ba5a8-ff19-458f-8d4c-fbb9b0ca5dee  ...  DODG -CAR/SUV 2021-11-01
# 1343322  f0dc0d15-b301-408a-a6e2-338645cf2875  ...  HOND -CAR/SUV 2021-10-27
# 1343323  c98f0f0c-574c-483d-abe2-646fd8a4ce58  ...           Nova 2021-10-27
# 1343324  f0dc0d15-b301-408a-a6e2-338645cf2875  ...  HOND -CAR/SUV 2021-10-27
# 1343325  c98f0f0c-574c-483d-abe2-646fd8a4ce58  ...           Nova 2021-10-27
#
#         CRASH_TIME HOURLY_INTERVAL  DAY  WEEK  MONTH  YEAR  FACTOR_ID  \
# 0            15:40              15   22    29      7  2016      15004
# 1            15:40              15   22    29      7  2016      15004
# 2            15:40              15   22    29      7  2016      15004
# 3            15:40              15   22    29      7  2016      15004
# 4            21:05              21   13    32      8  2016      15005
# ...            ...             ...  ...   ...    ...   ...        ...
# 1343321      17:57              17    1    44     11  2021    1052773
# 1343322      16:00              16   27    43     10  2021    1052775
# 1343323      16:00              16   27    43     10  2021    1052775
# 1343324      16:00              16   27    43     10  2021    1052775
# 1343325      16:00              16   27    43     10  2021    1052775
#
#                 CONTRIBUTING_FACTOR_1_y
# 0                           Unspecified
# 1                           Unspecified
# 2                           Unspecified
# 3                           Unspecified
# 4                           Unspecified
# ...                                 ...
# 1343321  Driver Inattention/Distraction
# 1343322              Turning Improperly
# 1343323              Turning Improperly
# 1343324              Turning Improperly
# 1343325              Turning Improperly
#
# [1343326 rows x 21 columns]

# %%
vehicle_facts = drop_unused_columns(fact_vehicle_merged_vehicle_merged_date_merged_factor, ['VEHICLE_TYPE_x', 'VEHICLE_MAKE_x',
       'VEHICLE_OCCUPANTS', 'POINT_OF_IMPACT', 'VEHICLE_DAMAGE',
       'CONTRIBUTING_FACTOR_1_y', 'ID','FACTOR_ID',
       'VEHICLE_ID_y', 'VEHICLE_TYPE_y', 'VEHICLE_MAKE_y',
       'CRASH_TIME', 'HOURLY_INTERVAL', 'DAY', 'WEEK', 'MONTH', 'YEAR'])

# %%
vehicle_facts.drop_duplicates(keep='first')
# Out:
#          COLLISION_ID                          VEHICLE_ID_x  \
# 0             3487936                                554272
# 2             3487936                                554271
# 4             3499697                                650962
# 5             4229563  86a294b4-6672-4a7e-8357-39d6d2eff9f7
# 7             4229563  ca744068-6013-47f0-a661-a0fbb579eb47
# ...               ...                                   ...
# 1343317       4473267  3e2caed9-0b40-4f70-a661-8cc7e8b353b8
# 1343319       4473267  c85dfca0-4653-48a9-bf25-0c94770adf44
# 1343321       4473641  b90ba5a8-ff19-458f-8d4c-fbb9b0ca5dee
# 1343322       4473807  f0dc0d15-b301-408a-a6e2-338645cf2875
# 1343324       4473807  c98f0f0c-574c-483d-abe2-646fd8a4ce58
#
#                 CONTRIBUTING_FACTOR_1_x CRASH_DATE
# 0                           Unspecified 2016-07-22
# 2        Driver Inattention/Distraction 2016-07-22
# 4                           Unspecified 2016-08-13
# 5                           Unspecified 2019-10-21
# 7                           Unspecified 2019-10-21
# ...                                 ...        ...
# 1343317  Passing or Lane Usage Improper 2021-11-01
# 1343319                     Unspecified 2021-11-01
# 1343321  Driver Inattention/Distraction 2021-11-01
# 1343322              Turning Improperly 2021-10-27
# 1343324                     Unspecified 2021-10-27
#
# [635136 rows x 4 columns]

# %% [markdown]
# # Load Tables to Bigquery

# %%
key_path = r'C:\Users\Kven\Desktop\baruch\courses\CIS9440\project\Milestone_3\tidal-heading-324722-9a9aa5afb1f2.json'

# %%
big_query_client = establish_bigquery_connection(key_path
                                      ,scopes_url = r'https://www.googleapis.com/auth/cloud-platform')

# %%
# load DimPerson Table to Bigquery
load_table_to_bigquery(big_query_client,
                               dim_person,
                               'milestone3',
                               'dim_person')
# Out:
# -----
#  loading dim_person to BigQuery dataset milestone3
# Loaded 2267538 rows and 10 columns to tidal-heading-324722.milestone3.dim_person
# -----

# %%
# load DimCollision Table to Bigquery
load_table_to_bigquery(big_query_client,
                               dim_collision,
                               'milestone3',
                               'dim_collision')
# Out:
# -----
#  loading dim_collision to BigQuery dataset milestone3
# Loaded 828356 rows and 2 columns to tidal-heading-324722.milestone3.dim_collision
# -----

# %%
# load DimLocation Table to Bigquery
load_table_to_bigquery(big_query_client,
                               dim_location,
                               'milestone3',
                               'dim_location')
# Out:
# -----
#  loading dim_location to BigQuery dataset milestone3
# Loaded 68986 rows and 8 columns to tidal-heading-324722.milestone3.dim_location
# -----

# %%
# load DimVehicle Table to Bigquery
load_table_to_bigquery(big_query_client,
                               dim_vehicle,
                               'milestone3',
                               'dim_vehicle')
# Out:
# -----
#  loading dim_vehicle to BigQuery dataset milestone3
# Loaded 1856325 rows and 5 columns to tidal-heading-324722.milestone3.dim_vehicle
# -----

# %%
# load DimFactors Table to Bigquery
load_table_to_bigquery(big_query_client,
                               dim_factors,
                               'milestone3',
                               'dim_factors')
# Out:
# -----
#  loading dim_factors to BigQuery dataset milestone3
# Loaded 1037795 rows and 3 columns to tidal-heading-324722.milestone3.dim_factors
# -----

# %%
# load DimDate Table to Bigquery
load_table_to_bigquery(big_query_client,
                               dim_date,
                               'milestone3',
                               'dim_date')
# Out:
# -----
#  loading dim_date to BigQuery dataset milestone3
# Loaded 828356 rows and 8 columns to tidal-heading-324722.milestone3.dim_date
# -----

# %%
# load Person Facts Table to Bigquery
load_table_to_bigquery(big_query_client,
                               person_facts,
                               'milestone3',
                               'person_facts')
# Out:
# -----
#  loading person_facts to BigQuery dataset milestone3
# Loaded 2247010 rows and 4 columns to tidal-heading-324722.milestone3.person_facts
# -----

# %%
# load Crash Facts Table to Bigquery
load_table_to_bigquery(big_query_client,
                               crash_facts,
                               'milestone3',
                               'crash_facts')
# Out:
# -----
#  loading crash_facts to BigQuery dataset milestone3
# Loaded 635136 rows and 8 columns to tidal-heading-324722.milestone3.crash_facts
# -----

# %%
# load Vehicle Facts Table to Bigquery
load_table_to_bigquery(big_query_client,
                               vehicle_facts,
                               'milestone3',
                               'vehicle_facts')
# Out:
# -----
#  loading vehicle_facts to BigQuery dataset milestone3
# Loaded 1343326 rows and 4 columns to tidal-heading-324722.milestone3.vehicle_facts
# -----
